# %% [markdown]
# # Lab 3: CNNs and Deep Learning
#
# ## TBMI26/732A55 Neural Networks and Learning Systems
#
# ### Michael Felsberg

# %% [markdown]
# ## 2D Convolution
# For the further steps, we often need to visualize an image and we define a shortcut for that:

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

def visualize(img):
    plt.imshow(img,'gray')
    plt.colorbar()
    plt.show()
    print('Image size:', img.shape)

# %% [markdown]
# Convolution can be performed in 2D using the function `scipy.signal.convolve2d()`.
#
# **Task 1:** Use this function to generate a 2D kernel of size $33\times33$ by five times cascading 2D convolutions of $h$ with itself, starting with $h = \begin{array}{|c|c|}
#       \hline
#       \frac{1}{4} & \frac{1}{4} \\
#       \hline
#       \frac{1}{4} & \frac{1}{4} \\
#       \hline
#     \end{array}$. Visualize the kernel.

# %%
import scipy
from scipy import signal
import numpy as np

h_task1=np.array([[1/4,1/4],
          [1/4,1/4]])
for i in range(5):
    h_task1 = scipy.signal.convolve2d(h_task1,h_task1)
visualize(h_task1)
# Out:
# Image size: (33, 33)

# %% [markdown]
# **Task 2:** Now, load the image 'MR15^044.JPG' (a sample from ImageNet), convert it to gray-scale by summing its  R-, G-, and B-values at each pixel, and normalize it to the interval $[0;1]$. Convolve it with $h$ from the previous task with the options `'valid'` and `'same'`. Visualize all three images. What differences do you observe regarding the size and intensity of the output?

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

im = plt.imread("MR15^044.JPG")
grayIm = rgb2gray(im)
valid = scipy.signal.convolve2d(grayIm,h_task1,mode = 'valid')
same = scipy.signal.convolve2d(grayIm,h_task1,mode = 'same')
visualize(grayIm)
visualize(same)
visualize(valid)
# Out:
# Image size: (246, 248)
# Image size: (246, 248)
# Image size: (214, 216)

# %% [markdown]
# Strided convolution removes samples. According to the Nyquist theorem, this can generate aliasing artifacts.
#
# **Task 3:** Visualize the original gray-scale image and the output image from the previous task (with option `'same'`) with only keping every fifth row and column (stride 5). What do you observe, in particular at the ski?

# %%
deci = same[::5,1::5]
visualize(deci)
visualize(grayIm[::5,::5])
# Out:
# Image size: (50, 50)
# Image size: (50, 50)

# %% [markdown]
# **Task 3 answer:**
# Images looks better when low-pass filtering is done before downsampling.

# %% [markdown]
# ## Convolution  in TensorFlow
# We will now repeat the same steps in TensorFlow, where we will exploit its capability to perform *eager execution*. This is initialized as follows:

# %%
import tensorflow as tf

print('TensorFlow version '+tf.__version__)
tf.enable_eager_execution()
if tf.executing_eagerly():
    print('Eager execution activated!')
# Out:
# TensorFlow version 1.9.0
# Eager execution activated!

# %% [markdown]
# TensorFlow allows to map from and to numpy. Also, operations are automatically casted. In order to get used to TensorFlow and the casting, we repeat the convolution 1.a) from class 5 (see Lisam). As you have learned in the lecture, any convolution with kernel $h$ can also be performed as matrix multiplication by the Toeplitz matrix $H$.
#
# **Task 4:**  Use `scipy.linalg.toeplitz` to generate the matrix $H$ for the kernel $h= \begin{array}{|c|c|c|}
#       \hline
#       \hphantom{-}1 & \hphantom{-}\textbf{2} & -2 \\
#       \hline
#     \end{array}$ and boundary condition `'same'` and $f= \begin{array}{|c|c|c|c|c|c|c|c|}
#       \hline
#       \hphantom{-}1 & -1 & -2 & \hphantom{-}\textbf{0} & -1 & \hphantom{-}1 & \hphantom{-}2 & -1 \\
#       \hline
#     \end{array}$ in TensorFlow (`tf.constant()`). Multiply $H$ and $f$ and display the result. Verify that the result is the same as in 1.a). What are the respective classes of $H$, $f$, and the result?
#     Hints: `scipy.linalg.toeplitz` can take the first column and row as input; `[*np.zeros()]=np.zeros()` (`*` dereferences all elements of a tuple)

# %%
H = scipy.linalg.toeplitz([2,-2,0,0,0,0,0,0],[2,1,0,0,0,0,0,0])
f = np.atleast_2d(tf.constant([1,-1,-2,0,-1,1,2,-1]))
f = tf.transpose(f)
H@f
# Out:
# <tf.Tensor: id=14, shape=(8, 1), dtype=int32, numpy=
# array([[ 1],
#        [-6],
#        [-2],
#        [ 3],
#        [-1],
#        [ 6],
#        [ 1],
#        [-6]], dtype=int32)>

# %% [markdown]
# Keras layers can be applied in eager mode using the `tf.keras.layers` package. **NOTE:**  `tf.keras.layers` and **NOT** `keras.layers`.
#
# **Task 5:** Perform the convolution from the previous task using a convolution layer `Conv1D` and a (trivial) `Sequential` model from `tf.keras`.
# Hints: RTFM of `tf.keras.Sequential` - weights can be set for the model (list) or the layer (by traversing the layers list). Apply `use_bias=False` to avoid random DC-shifts.

# %%
h = np.array([[[[-2,2,1]]]]).transpose((0,3,1,2)).astype(np.float32)

model = tf.keras.Sequential([tf.keras.layers.Conv1D(1,3,padding = 'same',use_bias=False, input_shape=(8,1))])

model.set_weights(h)

f = np.array([[[1,-1,-2,0,-1,1,2,-1]]]).transpose((0,2,1)).astype(np.float32)
out = model(f)
print(out)
# Out:
# tf.Tensor(
# [[[ 1.]
#   [-6.]
#   [-2.]
#   [ 3.]
#   [-1.]
#   [ 6.]
#   [ 1.]
#   [-6.]]], shape=(1, 8, 1), dtype=float32)

# %% [markdown]
# **Task 6:** Apply the cascaded $33\times33$ filter from task 1 to the image from task 2 using a `Conv2D` layer. Compare the result visually and by subtracting the fitting result from task 2.

# %%
h_task6 = np.array([[h_task1]]).transpose(2,3,1,0)
grayIm6 = np.array([[grayIm]]).transpose(0,2,3,1)

model = tf.keras.Sequential([tf.keras.layers.Conv2D(1,(33,33),padding = 'same',use_bias=False, input_shape = (246,248,1))])
#print(model.get_weights())

model.set_weights([h_task6])
out6 = model(grayIm6.astype(np.float32))
visualize(out6[-1,:,:,-1])
visualize(same)
visualize(out6[-1,:,:,-1]-same.astype(np.float32))
# Out:
# Image size: (246, 248)
# Image size: (246, 248)
# Image size: (246, 248)

# %% [markdown]
# **Task 7:** Repeat the previous task with stride 5 and compare the result visually and by subtracting the fitting result from task 3. Repeat the task, but with a $1\times1$ filter (coefficient `1`) and stride 5. Compare again the result visually and by subtracting the fitting result from task 3.
# Hint: You might need to adjust the offset for the subsampling.

# %%
h_task7 = np.array([[h_task1]]).transpose(2,3,1,0)
grayIm7 = np.array([[grayIm]]).transpose(0,2,3,1)

model = tf.keras.Sequential([tf.keras.layers.Conv2D(1,(33,33), strides = (5,5),
                                                    padding = 'same',use_bias=False, input_shape = (246,248,1))])

model.set_weights([h_task7])
out = model(grayIm7.astype(np.float32))
visualize(out[-1,:,:,-1])
visualize(deci)
visualize(out[-1,:,:,-1]-deci.astype(np.float32))

h_task7 = np.array([[[[1]]]]).transpose(2,3,1,0)
grayIm7 = np.array([[grayIm]]).transpose(0,2,3,1)

model = tf.keras.Sequential([tf.keras.layers.Conv2D(1,1, strides = (5,5),
                                                    padding = 'same',use_bias=False, input_shape = (246,248,1))])

model.set_weights([h_task7])
out = model(grayIm7.astype(np.float32))
visualize(out[-1,:,:,-1])
visualize(grayIm[::5,::5])
visualize(out[-1,:,:,-1]-grayIm[::5,::5])
# Out:
# Image size: (50, 50)
# Image size: (50, 50)
# Image size: (50, 50)
# Image size: (50, 50)
# Image size: (50, 50)
# Image size: (50, 50)

# %% [markdown]
# We now define a new filter that is, unlike $h$, anti-symmetric:

# %%
fsz = 33
hfsz = 17
g = h_task1*(np.expand_dims(np.arange(-hfsz+1,hfsz),1)@np.ones((1,fsz)))
visualize(g)
# Out:
# Image size: (33, 33)

# %% [markdown]
# **Task 8:** repeat tasks 6 & 7 with $g$ instead of $h$. What difference do you observe and why?

# %%
g8= np.array([[g]]).transpose(2,3,1,0)
grayIm8 = np.array([[grayIm]]).transpose(0,2,3,1)

model = tf.keras.Sequential([tf.keras.layers.Conv2D(1,(33,33),padding = 'same',use_bias=False, input_shape = (246,248,1))])
#print(model.get_weights())

model.set_weights([g8])
out = model(grayIm8.astype(np.float32))
visualize(out[-1,:,:,-1])
visualize(same)
visualize(out[-1,:,:,-1]-same.astype(np.float32))

model = tf.keras.Sequential([tf.keras.layers.Conv2D(1,(33,33), strides = (5,5),
                                                    padding = 'same',use_bias=False, input_shape = (246,248,1))])

model.set_weights([g8])
out = model(grayIm8.astype(np.float32))
visualize(out[-1,:,:,-1])
visualize(deci)
visualize(out[-1,:,:,-1]-deci.astype(np.float32))
# Out:
# Image size: (246, 248)
# Image size: (246, 248)
# Image size: (246, 248)
# Image size: (50, 50)
# Image size: (50, 50)
# Image size: (50, 50)

# %% [markdown]
# **Task 8 answer** The filter is now a derivative filter in the y-axis.

# %% [markdown]
# ## Training layers
# We now take the input and output from task 6 as training data (input and output) for supervised learning of a convolution layer.
# **Task 9:** Although we only have a single input and output image, we can expect the training to work, although this usually requires multiple samples. Why? Define two tensors `batch` and `label` that contain the data from task 6.

# %%
batch = tf.constant(grayIm6.astype(np.float32)) 
batch = batch / tf.reduce_max(batch)
label = tf.constant(out6) 
label = label / tf.reduce_max(label)

visualize(batch[0,:,:,0])
visualize(label[0,:,:,0])
# Out:
# Image size: (246, 248)
# Image size: (246, 248)

# %% [markdown]
# **Task 9 answer** This will work because we keep iterating over the image, so the model will learn the kernel for this image.

# %% [markdown]
# **Task 10:** We want to apply the L1-loss. Define a suitable function `loss(model, x, y)` that can be used during training.

# %%
def loss(model,x,y):
    return tf.reduce_mean(tf.abs(model(x) - y))

# %% [markdown]
# Training a layers requires computing the gradient. For TF in eager mode, we use `GradientTape()` for this purpose.
# **Task 11:** Train the model from task 6 (but without assigning the weights) using the data from task 9, the loss from task 10, and `GradientDescentOptimizer()`. During training, print the loss every 100 steps and visualize the learned kernel after training.
# Hint: add a kernel_constraint to be non-negative.

# %%
from tensorflow.train import GradientDescentOptimizer 
optimizer = GradientDescentOptimizer(learning_rate=0.0001)
model = tf.keras.Sequential([tf.keras.layers.Conv2D(1,(33,33),padding = 'same',use_bias=False, input_shape = (246,248,1)
                                                   ,kernel_constraint=tf.keras.constraints.NonNeg())])
train_steps = 10000
for i in range(train_steps):
    with tf.GradientTape() as tape:
        loss_value = loss(model, batch, label)
        if i%100==0: print(loss_value)
        if(loss_value < 0.004): break #Increases after loss around 0.4
    dw = tape.gradient(loss_value, model.variables)
    optimizer.apply_gradients(zip(dw, model.variables))
# Out:
# tf.Tensor(0.9308427, shape=(), dtype=float32)
# tf.Tensor(4.298117, shape=(), dtype=float32)
# tf.Tensor(3.5431097, shape=(), dtype=float32)
# tf.Tensor(2.8541584, shape=(), dtype=float32)
# tf.Tensor(2.2235239, shape=(), dtype=float32)
# tf.Tensor(1.6480426, shape=(), dtype=float32)
# tf.Tensor(1.1460513, shape=(), dtype=float32)
# tf.Tensor(0.7264723, shape=(), dtype=float32)
# tf.Tensor(0.37831944, shape=(), dtype=float32)
# tf.Tensor(0.15116856, shape=(), dtype=float32)
# tf.Tensor(0.09530802, shape=(), dtype=float32)
# tf.Tensor(0.08848133, shape=(), dtype=float32)
# tf.Tensor(0.08224755, shape=(), dtype=float32)
# tf.Tensor(0.07618188, shape=(), dtype=float32)
# tf.Tensor(0.07023799, shape=(), dtype=float32)
# tf.Tensor(0.06449848, shape=(), dtype=float32)
# tf.Tensor(0.058970757, shape=(), dtype=float32)
# tf.Tensor(0.053749867, shape=(), dtype=float32)
# tf.Tensor(0.04881233, shape=(), dtype=float32)
# tf.Tensor(0.044159416, shape=(), dtype=float32)
# tf.Tensor(0.03979482, shape=(), dtype=float32)
# tf.Tensor(0.035703063, shape=(), dtype=float32)
# tf.Tensor(0.031964093, shape=(), dtype=float32)
# tf.Tensor(0.02853915, shape=(), dtype=float32)
# tf.Tensor(0.025294345, shape=(), dtype=float32)
# tf.Tensor(0.02227432, shape=(), dtype=float32)
# tf.Tensor(0.019535081, shape=(), dtype=float32)
# tf.Tensor(0.017129194, shape=(), dtype=float32)
# tf.Tensor(0.01494183, shape=(), dtype=float32)
# tf.Tensor(0.012953231, shape=(), dtype=float32)
# tf.Tensor(0.01123109, shape=(), dtype=float32)
# tf.Tensor(0.0096521005, shape=(), dtype=float32)
# tf.Tensor(0.008213114, shape=(), dtype=float32)
# tf.Tensor(0.0069689755, shape=(), dtype=float32)
# tf.Tensor(0.0058446955, shape=(), dtype=float32)
# tf.Tensor(0.0048651085, shape=(), dtype=float32)
# tf.Tensor(0.004003254, shape=(), dtype=float32)

# %%
w_trained = model.get_weights()
visualize(w_trained[0][:,:,0,0])
# Out:
# Image size: (33, 33)

# %% [markdown]
# The result can be improved in several ways: data augmentation (e.g. by flipping the image, using the three RGB-channel separately), regularizing the weights (e.g. using the L1-norm), and replacing the optimizer (e.g., ADAM).
# **Extra task (not to be done before task 14 is completed):** Try to improve the result using one or several of the mentioned approaches.

# %% [markdown]
# ## Training a whole network
# So far, we have been training a single layer and we have been following the progress with the help of the Eager mode. If we want to train a whole network, it is much better to leave the Eager mode and to compile the graph. For this, we need to kill the notebook kernel ("Kernel" -> "Restart"). After that, we continue below in the classical TensorFlow mode.

# %%
import tensorflow as tf
print('TensorFlow version '+tf.__version__)
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
# Out:
# TensorFlow version 1.9.0

# %% [markdown]
# **Task 12:** We will train on CIFAR10, which is contained in `keras.datasets`. Download the dataset, show a sample for each class, convert the labels to one-hot coding, and normalize the images.

# %%
from keras.datasets import cifar10
from keras.utils import to_categorical
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train / 255
x_test = x_test / 255

#one_hot 
y_train_ohot = to_categorical(y_train, 10)
y_test_ohot = to_categorical(y_test, 10)


for i in range(np.size(y_train)):
    if(i < 10):
        plt.imshow(x_train[i])
        plt.colorbar()
        plt.show()
    
plt.imshow(x_train[6])
plt.colorbar()
plt.show()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Task 13:** Build the depicted LeNet5-inspired model using Keras standard components.
# ![title](model.png)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.constraints import maxnorm
from keras.optimizers import Adam, rmsprop
from keras.layers import Activation
from keras import regularizers

def base_model():
    model = Sequential()
    model.add(Conv2D(32, (3,3), padding='same', input_shape=x_train.shape[1:]))
    model.add(Activation('elu'))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3,3), padding='same'))
    model.add(Activation('elu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, (3,3), padding='same'))
    model.add(Activation('elu'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3,3), padding='same'))
    model.add(Activation('elu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))
    model.add(Conv2D(128, (3,3), padding='same'))
    model.add(Activation('elu'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3,3), padding='same'))
    model.add(Activation('elu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.4))

    model.add(Flatten())
    model.add(Dense(10, activation='softmax'))

    opt = Adam(lr=0.001, decay=1e-6)

    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
   
    return model

#m = base_model()

# %% [markdown]
# We will now train the network. For displaying the performance we define a helper function:

# %%
def plot_model_history(model):
    line_w = 3
    fig_size = (8, 6)
    plt.figure(0)
    plt.plot(model.history['acc'],'r', lw=line_w)
    plt.plot(model.history['val_acc'],'b', lw=line_w)
    plt.rcParams['figure.figsize'] = fig_size
    plt.xlabel("Epoch number")
    plt.ylabel("Accuracy")
    plt.title("Training Accuracy vs Validation Accuracy")
    plt.legend(['Training','Validation'])
    plt.grid(True)

# %% [markdown]
# **Task 14:** Train the defined model for 50 epochs and a suitable batch size and display the result.

# %%
model = base_model()
model_history = model.fit(x_train,y_train_ohot,epochs=50,batch_size=512,validation_data=(x_test,y_test_ohot),verbose=0)
plot_model_history(model_history)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-054e7d376e37> in <module>
# ----> 1 model = base_model()
#       2 model_history = model.fit(x_train,y_train_ohot,epochs=50,batch_size=512,validation_data=(x_test,y_test_ohot),verbose=0)
#       3 plot_model_history(model_history)
#
# <ipython-input-18-94dfc332e691> in base_model()
#      10 def base_model():
#      11     model = Sequential()
# ---> 12     model.add(Conv2D(32, (3,3), padding='same', input_shape=x_train.shape[1:]))
#      13     model.add(Activation('elu'))
#      14     model.add(BatchNormalization())
#
# /opt/TBMI26/2019-02-20.3/lib/python3.6/site-packages/keras/engine/sequential.py in add(self, layer)
#     159                         batch_shape=batch_shape,
#     160                         dtype=dtype,
# --> 161                         name=layer.name + '_input')
#     162                     # This will build the current layer
#     163                     # and create the node connecting the current layer
#
# /opt/TBMI26/2019-02-20.3/lib/python3.6/site-packages/keras/engine/input_layer.py in Input(shape, batch_shape, name, dtype, sparse, tensor)
#     176                              name=name, dtype=dtype,
#     177                              sparse=sparse,
# --> 178                              input_tensor=tensor)
#     179     # Return tensor including _keras_shape and _keras_history.
#     180     # Note that in this case train_output and test_output are the same pointer.
#
# /opt/TBMI26/2019-02-20.3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /opt/TBMI26/2019-02-20.3/lib/python3.6/site-packages/keras/engine/input_layer.py in __init__(self, input_shape, batch_size, batch_input_shape, dtype, input_tensor, sparse, name)
#      85                                          dtype=dtype,
#      86                                          sparse=self.sparse,
# ---> 87                                          name=self.name)
#      88         else:
#      89             self.is_placeholder = False
#
# /opt/TBMI26/2019-02-20.3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in placeholder(shape, ndim, dtype, sparse, name)
#     515         x = tf.sparse_placeholder(dtype, shape=shape, name=name)
#     516     else:
# --> 517         x = tf.placeholder(dtype, shape=shape, name=name)
#     518     x._keras_shape = shape
#     519     x._uses_learning_phase = False
#
# /opt/TBMI26/2019-02-20.3/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in placeholder(dtype, shape, name)
#    1729   """
#    1730   if context.executing_eagerly():
# -> 1731     raise RuntimeError("tf.placeholder() is not compatible with "
#    1732                        "eager execution.")
#    1733
#
# RuntimeError: tf.placeholder() is not compatible with eager execution.

# %% [markdown]
# The results can be improved in several ways, e.g., by successively reducing the learning rate (divided by two after 30 and 40 epochs), by data augmentation (`ImageDataGenerator`), and by weight regularization (see above).
# **Extra task:** Try to improve the result using one or several of the mentioned approaches.
# Hint: you need to define a suitable callback function to change the learning rate during training.
